# %% [markdown]
# Weak perturbation
# =================

# %%
import os
import sys

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.ndimage import gaussian_filter1d as gf
from numpy import polyfit
from scipy.signal import find_peaks
#  %matplotlib widget

# %%
from pyphare.pharesee.run import Run

# %%
home = os.environ['HOME']
root_path = os.path.join(home, "far/farTeach/2026/run/weak")
phare_path = os.path.join(home, "far/PHARE")

# %%
phare_root = os.path.expanduser(phare_path)
sys.path.append(os.path.join(phare_root, "pyphare"))

# %% [markdown]
# # Misc functions to get data

# %%
def get_velocities(r, times, sigma):
    for it,t in enumerate(times):
        Vi = r.GetVi(t) # , merged=True)
        print(type(Vi), dir(Vi), type(Vi['x']))
        Vix = Vi["x"][0]
        xV = Vi["x"][1][0]
        v = gf(Vix(xV), sigma)
        if it==0 :
            vt = np.zeros((len(v),len(times)))
        vt[:,it] = v
    return xV, vt

# %% [markdown]
# # WP1

# %%
Te = 0.05
path = root_path+"/"+"wp_0.05"

# %%
times = np.asarray((0, 20, 40, 60, 80, 100))
r = Run(path)
x, Vs = get_velocities(r, times, sigma=6)
# Out:
# <class 'pyphare.pharesee.hierarchy.vectorfield.VectorField'> ['__add__', '__call__', '__class__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__weakref__', '_default_time', '_quantities', '_sim', 'add_time', 'box_to_Rectangle', 'data_files', 'dist_plot', 'domain_box', 'finest_level', 'global_max', 'global_min', 'has_file', 'has_time', 'is_homogeneous', 'level', 'levelNbr', 'levelNbrs', 'level_domain_box', 'levels', 'names', 'nbrPatches', 'nbytes', 'ndim', 'patch_levels', 'plot', 'plot1d', 'plot2d', 'plot_2d_patches', 'plot_patches', 'quantities', 'refined_domain_box', 'refinement_ratio', 'selection_box', 'sim', 'time_hier', 'times', 'update', 'x', 'y', 'z'] <class 'pyphare.pharesee.hierarchy.hierarchy.PatchHierarchy'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 3
#       1 times = np.asarray((0, 20, 40, 60, 80, 100))
#       2 r = Run(path)
# ----> 3 x, Vs = get_velocities(r, times, sigma=6)
#
# Cell In[20], line 5, in get_velocities(r, times, sigma)
#       3 Vi = r.GetVi(t) # , merged=True)
#       4 print(type(Vi), dir(Vi), type(Vi['x']))
# ----> 5 Vix = Vi["x"][0]
#       6 xV = Vi["x"][1][0]
#       7 v = gf(Vix(xV), sigma)
#
# File ~/far/PHARE/pyphare/pyphare/pharesee/hierarchy/hierarchy.py:77, in PatchHierarchy.__getitem__(self, qty)
#      76 def __getitem__(self, qty):
# ---> 77     return self.__dict__[qty]
#
# KeyError: 0

# %%
positions, amplitudes = get_peaks(x,Vs)
profiles(times, x, Vs, positions, Te)

# %%
propagation(times, positions, Te)

# %%
damping(times, amplitudes)

# %%
time=100
r = Run(root_path+"/"+"wp1")
ions = r.GetParticles(time, ["protons",])
fig, ax1 = plt.subplots(figsize=(10,4))
p,f = ions.dist_plot(axis=("x", "Vx"),
                     ax=ax1,            # default creates the figure
                     norm = 0.4,     # max value, min is 0
                     finest=True,  # only consider finest particles possible
                     gaussian_filter_sigma=1,
                     vmin=-1,vmax=1,
                     dv=0.01,
                     title="weak perturbation at time : {:.2f}".format(time), # figure title
                    )

# %%
Te = 0.05
Ti = 0.01
Gamma_e = 1
Gamma_i = 3
print("ion acoustic speed : ", np.sqrt(Gamma_e*Te+Gamma_i*Ti))
